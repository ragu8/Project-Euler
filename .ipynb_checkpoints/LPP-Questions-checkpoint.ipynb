# %% [markdown]
# # Linear Programming Problems

# %% [markdown]
# ##  Graphical Method

# %% [markdown]
# ![image.png](attachment:a3828cd2-9a36-4e4f-ad39-e9faeee1104a.png)

# %% [markdown]
# ![image.png](attachment:2663db56-65e9-4c70-b67b-8e8d2dc86719.png)

# %% [markdown]
# ## Simplex Method

# %% [markdown]
# ![image.png](attachment:bc39070a-f2fe-408d-9817-037756902fb7.png)

# %% [markdown]
# ![image.png](attachment:3bb806db-8378-41a0-a301-82f4532b56b8.png)

# %% [markdown]
# ## Transportation Problem

# %% [markdown]
# ![image.png](attachment:6fe167f5-cb20-414e-9c9c-38a52c42e104.png)

# %% [markdown]
# ## Assignment Problem

# %% [markdown]
# ![image.png](attachment:8f7063b6-3f23-4b87-8f6a-ed3e3e953a40.png)
